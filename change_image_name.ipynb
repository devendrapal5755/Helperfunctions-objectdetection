# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.getcwd()
collection = "/content/drive/MyDrive/Ross_clip19"

# %%
for i, filename in enumerate(os.listdir(collection)):
         os.rename("/content/drive/MyDrive/Ross_clip19/" + filename , "/content/drive/MyDrive/Ross_clip19/Ross01" + str(i)+ ".png")

# %%
path = "/media/oem/DNW2/yolov5/yolov5/data/val/"

# %%
import os
for i , filename in enumerate(os.listdir(path)):
    if filename[-3:]=="txt":
        file=open(path+filename , 'r')
        x= file.readline()
        
        print(filename, x.split(" "))
# Out:
# DJI_2206.txt ['0', '0.469125', '0.660167', '0.059750', '0.075667\n']
# DJI_0007.txt ['0', '0.476625', '0.546667', '0.066750', '0.129333\n']
# DJI_0731.txt ['0', '0.437125', '0.430167', '0.032250', '0.031000\n']
# DJI_0867.txt ['0', '0.394000', '0.789333', '0.044000', '0.044667\n']
# DJI_0481.txt ['0', '0.630625', '0.441667', '0.024250', '0.033333\n']
# DJI_2113.txt ['0', '0.661875', '0.463000', '0.036750', '0.035333\n']
# DJI_0213.txt ['0', '0.564250', '0.687833', '0.045500', '0.064333\n']
# DJI_0661.txt ['0', '0.503750', '0.495167', '0.060000', '0.079667\n']
# DJI_0875.txt ['0', '0.100250', '0.648167', '0.068000', '0.043667\n']
# DJI_0571.txt ['0', '0.425625', '0.545500', '0.061750', '0.083667\n']
# DJI_2211.txt ['0', '0.539500', '0.624333', '0.042500', '0.070667\n']
# DJI_0257.txt ['0', '0.450125', '0.418833', '0.042750', '0.057667\n']
# DJI_2338.txt ['0', '0.425875', '0.664667', '0.051250', '0.030667\n']
# DJI_2277.txt ['0', '0.362250', '0.504667', '0.045000', '0.091333\n']
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-920131bb12b6> in <module>
# ----> 1 len(False) in y
#
# TypeError: object of type 'bool' has no len()
